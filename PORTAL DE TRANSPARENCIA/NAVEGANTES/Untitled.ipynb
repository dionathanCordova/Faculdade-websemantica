# %%
import pandas as pd

# %%
df = pd.read_csv('quadroPessoal.csv', sep=';')

# %%
#df.columns = ['teste', 'test', 'test', 'test', 'test', 'test', 'test', 'test', 'test', 'test']

# %%
df
# Out:
#                               Descrição da vaga Lei Decreto        Ato  \
# 0                                    JORNALISTA    149/2012        NaN
# 1                       TECNICO ATIV COMPLEMENT    011/2003        NaN
# 2                 CONTADOR PREVIDENCIARIO  40 H         206    65/2016
# 3     PROCURADOR AUTÁRQUICO PREVIDENCIÁRIO 40 H         206    14/2015
# 4                SECRETÁRIA RECEPCIONISTA  40 H    100/2011     dez/15
# 5        TECNICO ADMINISTRATIVO FINANCEIRO 40 h    100/2011    48/2016
# 6                            ASSESSOR TECNICO I    135/2011   273/2013
# 7                           ASSESSOR TECNICO II    317/2017   486/2013
# 8                                CHEFE DE SEÇÃO    184/2013   706/2013
# 9                                CHEFE DE SEÇÃO    184/2013  2198/2015
# 10                               CHEFE DE SEÇÃO    184/2013  1659/2018
# 11                               CHEFE DE SEÇÃO    184/2013  2258/2019
# ...

# %%
df = pd.read_csv('Quadro_quantitativo_por_tipo_de_cargo_2.csv', sep=';')

# %%
df
# Out:
#            Descrição da vaga Lei Decreto  Ato  Matrícula                Nome  \
# 0  AGENTE DE SERVIÇOS GERAIS   1573/2002  NaN          5     ODENIZIA REBELO
# 1        ASSISTENTE CONTABIL   1573/2002  NaN          4      VANILDO TELLES
# 2     ASSISTENTE LEGISLATIVO   1573/2002  NaN          3  SOLON MANUEL COSTA
#
#    Unnamed: 5  Unnamed: 6  CPF               Lotação  Unnamed: 9
# 0         NaN         NaN  NaN  201 - ADMINISTRATIVO         NaN
# 1         NaN         NaN  NaN  201 - ADMINISTRATIVO         NaN
# 2         NaN         NaN  NaN  201 - ADMINISTRATIVO         NaN
